# %% [markdown]
# ### Inspect the artifical data in the SQLite Databse

# %% [markdown]
# ##### Step 1: Connect to the database

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('database/opspilot.db')

# %% [markdown]
# ##### Step 2: Write a query
#
# Example queries:
# ~~~~sql
# SELECT * FROM monthly_kpis LIMIT 10;
# SELECT * FROM delay_reasons LIMIT 10;
# SELECT * FROM staffing_events LIMIT 10;
# SELECT * FROM customer_feedback LIMIT 10;

# %%
result = pd.read_sql_query("SELECT * from monthly_kpis limit 10;", conn)
result.head()
# Out:
#    id branch_id branch_name    month  service_level  delayed_shipments  \
# 0   1      B001     Hamburg  2025-06           96.7                135
# 1   2      B001     Hamburg  2025-07           96.9                127
# 2   3      B001     Hamburg  2025-08           96.0                173
# 3   4      B001     Hamburg  2025-09           97.1                122
# 4   5      B001     Hamburg  2025-10           97.1                121
#
#    complaints  staffing_level  transportation_costs  shipment_volume  \
# 0          24              46             113351.08             4114
# 1          22              45             115735.45             4112
# 2          24              46             121402.30             4327
# 3          18              46             122572.99             4238
# 4          23              45             118934.35             4190
#
#    damage_rate  overtime_hours  customer_satisfaction
# 0         0.65            57.6                   4.37
# ...
